# %% [markdown]
# <a href="https://colab.research.google.com/github/jsKim-prog/pythonStudy23_JS/blob/master/3%EC%A3%BC%EC%B0%A8_%EC%88%99%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import dart_fss as dart_fss
import pandas as pd

api_key = '*********myapikey'
dart_fss.set_api_key(api_key=api_key)
corp_list = dart_fss.get_corp_list()

corp_list.corps

# %%
all = dart_fss.api.filings.get_corp_code()

df = pd.DataFrame(all)
df_listed = df[df['stock_code'].notnull()]
df_non_listed = df[df['stock_code'].isnull()]
# Out:
# Output()

# %%
def get_salary(name):
  corp_code = df_listed[df_listed['corp_name'] == name].iloc[0,0]
  data = dart_fss.api.info.emp_sttus(corp_code, '2021', '11011')

  df = pd.DataFrame(data['list'])
  df = df[['corp_name','sexdstn','jan_salary_am']]

  df_result = pd.DataFrame()
  doc = {
      '기업명':name,
      '연봉(남)':df[df['sexdstn']=='남'].iloc[-1,-1],
      '연봉(여)':df[df['sexdstn']=='여'].iloc[-1,-1]
  }

  df_result = df_result.append(doc, ignore_index = True)

  df_result['연봉(남)'] = pd.to_numeric(df_result['연봉(남)'].str.replace(',',''))
  df_result['연봉(여)'] = pd.to_numeric(df_result['연봉(여)'].str.replace(',',''))

  return df_result

# %%
names = list(df_listed.sample(10)['corp_name'])

dfs = []
for name in names:
  try:
    df= get_salary(name)
    dfs.append(df)
  except:
    print(f'error-{name}')

df_result = pd.concat(dfs)
df_result['차이'] = abs(df_result['연봉(남)'] - df_result['연봉(여)'])

df_result.sort_values(by='차이',ascending=True)
# Out:
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# error-신지소프트
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# <ipython-input-3-1859991326d1>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_result = df_result.append(doc, ignore_index = True)
# error-위더스기술금융
#       기업명      연봉(남)     연봉(여)        차이
# 0   에스제이켐   33584000  30294000   3290000
# 0   코오롱인더   70955000  63638000   7317000
# 0   스타플렉스   53836000  38212000  15624000
# 0   스피어파워   49750000  29704000  20046000
# 0  아이에이치큐   57000000  33000000  24000000
# 0   일월지엠엘   42636000  13895000  28741000
# 0    교보증권  114470000  75708000  38762000
# 0  티에스넥스젠   86915000  43651000  43264000
